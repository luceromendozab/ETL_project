# %% [markdown]
# ###  FOLIUM

# %%
import folium 
import pandas as pd
from IPython.display import display

# %%
df= pd.read_csv("df_usa.csv")
df.head(4)
# Out:
#    Unnamed: 0          language           endangerment  latitude  longitude
# 0         156            Navajo             Vulnerable   35.8044  -108.4750
# 1         359             Sioux             Vulnerable   43.0588  -102.5244
# 2         443  O'odham (Akimel)  Definitely endangered   33.0590  -112.0479
# 3         444  O'odham (Tohono)  Definitely endangered   31.9186  -111.8798

# %%
# Creando el mapa base
#Hallamos las coordenadas promedio 
latitude_center = df['latitude'].mean()
longitude_center = df['longitude'].mean()
m = folium.Map(location=[latitude_center, longitude_center], zoom_start=13)

# %%
for i, row in df.iterrows():
    folium.Marker([row['latitude'], row['longitude']], 
                  popup='{}, {}'.format(row['language'], row['endangerment'])).add_to(m)
m.save('map.html')

# %%
display(m)

# %% [markdown]
# ### l

# %%
#conda install -c conda-forge basemap
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.13.0
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/iron
#
#   added / updated specs:
#     - basemap
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     basemap-1.3.6              |   py39hb5623b0_1         144 KB  conda-forge
#     basemap-data-1.3.2         |     pyhd8ed1ab_1        27.2 MB  conda-forge
#     brotli-1.0.9               |       hb7f2c08_8          19 KB  conda-forge
#     brotli-bin-1.0.9           |       hb7f2c08_8          17 KB  conda-forge
#     c-ares-1.18.1              |       h0d85af4_0         100 KB  conda-forge
#     ca-certificates-2022.12.7  |       h033912b_0         142 KB  conda-forge
#     certifi-2022.12.7          |     pyhd8ed1ab_0         147 KB  conda-forge
#     cycler-0.11.0              |     pyhd8ed1ab_0          10 KB  conda-forge
#     fonttools-4.38.0           |   py39ha30fb19_1         1.9 MB  conda-forge
#     freetype-2.10.4            |       h4cff582_1         890 KB  conda-forge
#     geos-3.11.1                |       hf0c8a7f_0         1.4 MB  conda-forge
#     giflib-5.2.1               |       hbcb3906_2          71 KB  conda-forge
#     jpeg-9e                    |       hac89ed1_2         260 KB  conda-forge
#     kiwisolver-1.4.4           |   py39h92daf61_1          63 KB  conda-forge
#     krb5-1.19.3                |       hb49756b_0         1.2 MB  conda-forge
#     lcms2-2.14                 |       h90f4b2a_0         248 KB  conda-forge
#     libblas-3.9.0              |16_osx64_openblas          13 KB  conda-forge
#     libbrotlicommon-1.0.9      |       hb7f2c08_8          64 KB  conda-forge
#     libbrotlidec-1.0.9         |       hb7f2c08_8          33 KB  conda-forge
#     libbrotlienc-1.0.9         |       hb7f2c08_8         303 KB  conda-forge
#     libcblas-3.9.0             |16_osx64_openblas          13 KB  conda-forge
#     libcurl-7.86.0             |       ha585b31_0         335 KB
#     libedit-3.1.20191231       |       h0678c8f_2         103 KB  conda-forge
#     libev-4.33                 |       haf1e3a3_1          99 KB  conda-forge
#     libgfortran-5.0.0          |11_3_0_h97931a8_27         143 KB  conda-forge
#     libgfortran5-11.3.0        |      h082f757_27         1.4 MB  conda-forge
#     liblapack-3.9.0            |16_osx64_openblas          13 KB  conda-forge
#     libopenblas-0.3.21         |openmp_h429af6e_3         9.6 MB  conda-forge
#     libssh2-1.10.0             |       h52ee1ee_2         221 KB  conda-forge
#     libtiff-4.4.0              |       h2cd0358_2         504 KB
#     libwebp-1.2.4              |       hfa4350a_0          84 KB  conda-forge
#     libwebp-base-1.2.4         |       h775f41a_0         385 KB  conda-forge
#     llvm-openmp-15.0.7         |       h61d9ccf_0         287 KB  conda-forge
#     lz4-c-1.9.3                |       he49afe7_1         155 KB  conda-forge
#     matplotlib-base-3.5.3      |   py39h03b9044_0         7.4 MB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     numpy-1.24.1               |   py39hdfa1d0c_0         5.8 MB  conda-forge
#     openssl-1.1.1s             |       hfd90126_1         1.6 MB  conda-forge
#     packaging-23.0             |     pyhd8ed1ab_0          40 KB  conda-forge
#     pillow-9.3.0               |   py39h81888ad_1         689 KB
#     proj-9.0.1                 |       h05f0992_1         2.8 MB  conda-forge
#     pyparsing-3.0.9            |     pyhd8ed1ab_0          79 KB  conda-forge
#     pyproj-3.3.1               |   py39h94c78e7_1         455 KB  conda-forge
#     pyshp-2.3.1                |     pyhd8ed1ab_0         941 KB  conda-forge
#     python-dateutil-2.8.2      |     pyhd8ed1ab_0         240 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     unicodedata2-15.0.0        |   py39ha30fb19_0         486 KB  conda-forge
#     zstd-1.5.2                 |       hcb37349_0         473 KB
#     ------------------------------------------------------------
#                                            Total:        68.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   basemap            conda-forge/osx-64::basemap-1.3.6-py39hb5623b0_1
#   basemap-data       conda-forge/noarch::basemap-data-1.3.2-pyhd8ed1ab_1
#   brotli             conda-forge/osx-64::brotli-1.0.9-hb7f2c08_8
#   brotli-bin         conda-forge/osx-64::brotli-bin-1.0.9-hb7f2c08_8
#   c-ares             conda-forge/osx-64::c-ares-1.18.1-h0d85af4_0
#   cycler             conda-forge/noarch::cycler-0.11.0-pyhd8ed1ab_0
#   fonttools          conda-forge/osx-64::fonttools-4.38.0-py39ha30fb19_1
#   freetype           conda-forge/osx-64::freetype-2.10.4-h4cff582_1
#   geos               conda-forge/osx-64::geos-3.11.1-hf0c8a7f_0
#   giflib             conda-forge/osx-64::giflib-5.2.1-hbcb3906_2
#   jpeg               conda-forge/osx-64::jpeg-9e-hac89ed1_2
#   kiwisolver         conda-forge/osx-64::kiwisolver-1.4.4-py39h92daf61_1
#   krb5               conda-forge/osx-64::krb5-1.19.3-hb49756b_0
#   lcms2              conda-forge/osx-64::lcms2-2.14-h90f4b2a_0
#   lerc               pkgs/main/osx-64::lerc-3.0-he9d5cce_0
#   libblas            conda-forge/osx-64::libblas-3.9.0-16_osx64_openblas
#   libbrotlicommon    conda-forge/osx-64::libbrotlicommon-1.0.9-hb7f2c08_8
#   libbrotlidec       conda-forge/osx-64::libbrotlidec-1.0.9-hb7f2c08_8
#   libbrotlienc       conda-forge/osx-64::libbrotlienc-1.0.9-hb7f2c08_8
#   libcblas           conda-forge/osx-64::libcblas-3.9.0-16_osx64_openblas
#   libcurl            pkgs/main/osx-64::libcurl-7.86.0-ha585b31_0
#   libdeflate         pkgs/main/osx-64::libdeflate-1.8-h9ed2024_5
#   libedit            conda-forge/osx-64::libedit-3.1.20191231-h0678c8f_2
#   libev              conda-forge/osx-64::libev-4.33-haf1e3a3_1
#   libgfortran        conda-forge/osx-64::libgfortran-5.0.0-11_3_0_h97931a8_27
#   libgfortran5       conda-forge/osx-64::libgfortran5-11.3.0-h082f757_27
#   liblapack          conda-forge/osx-64::liblapack-3.9.0-16_osx64_openblas
#   libnghttp2         pkgs/main/osx-64::libnghttp2-1.46.0-ha29bfda_0
#   libopenblas        conda-forge/osx-64::libopenblas-0.3.21-openmp_h429af6e_3
#   libpng             pkgs/main/osx-64::libpng-1.6.37-ha441bb4_0
#   libssh2            conda-forge/osx-64::libssh2-1.10.0-h52ee1ee_2
#   libtiff            pkgs/main/osx-64::libtiff-4.4.0-h2cd0358_2
#   libwebp            conda-forge/osx-64::libwebp-1.2.4-hfa4350a_0
#   libwebp-base       conda-forge/osx-64::libwebp-base-1.2.4-h775f41a_0
#   llvm-openmp        conda-forge/osx-64::llvm-openmp-15.0.7-h61d9ccf_0
#   lz4-c              conda-forge/osx-64::lz4-c-1.9.3-he49afe7_1
#   matplotlib-base    conda-forge/osx-64::matplotlib-base-3.5.3-py39h03b9044_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   numpy              conda-forge/osx-64::numpy-1.24.1-py39hdfa1d0c_0
#   packaging          conda-forge/noarch::packaging-23.0-pyhd8ed1ab_0
#   pillow             pkgs/main/osx-64::pillow-9.3.0-py39h81888ad_1
#   proj               conda-forge/osx-64::proj-9.0.1-h05f0992_1
#   pyparsing          conda-forge/noarch::pyparsing-3.0.9-pyhd8ed1ab_0
#   pyproj             conda-forge/osx-64::pyproj-3.3.1-py39h94c78e7_1
#   pyshp              conda-forge/noarch::pyshp-2.3.1-pyhd8ed1ab_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.2-pyhd8ed1ab_0
#   python_abi         conda-forge/osx-64::python_abi-3.9-2_cp39
#   six                conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#   unicodedata2       conda-forge/osx-64::unicodedata2-15.0.0-py39ha30fb19_0
#   zstd               pkgs/main/osx-64::zstd-1.5.2-hcb37349_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.10.11~ --> conda-forge::ca-certificates-2022.12.7-h033912b_0
#   certifi            pkgs/main/osx-64::certifi-2022.9.24-p~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-1.1.1q-hca72f7f_0 --> conda-forge::openssl-1.1.1s-hfd90126_1
#
#
#
# Downloading and Extracting Packages
# six-1.16.0           | 14 KB     | ##################################### | 100%
# basemap-data-1.3.2   | 27.2 MB   | ##################################### | 100%
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
# libedit-3.1.20191231 | 103 KB    | ##################################### | 100%
# libev-4.33           | 99 KB     | ##################################### | 100%
# lz4-c-1.9.3          | 155 KB    | ##################################### | 100%
# llvm-openmp-15.0.7   | 287 KB    | ##################################### | 100%
# libbrotlicommon-1.0. | 64 KB     | ##################################### | 100%
# certifi-2022.12.7    | 147 KB    | ##################################### | 100%
# liblapack-3.9.0      | 13 KB     | ##################################### | 100%
# pyparsing-3.0.9      | 79 KB     | ##################################### | 100%
# libbrotlidec-1.0.9   | 33 KB     | ##################################### | 100%
# brotli-bin-1.0.9     | 17 KB     | ##################################### | 100%
# libwebp-1.2.4        | 84 KB     | ##################################### | 100%
# kiwisolver-1.4.4     | 63 KB     | ##################################### | 100%
# ca-certificates-2022 | 142 KB    | ##################################### | 100%
# geos-3.11.1          | 1.4 MB    | ##################################### | 100%
# proj-9.0.1           | 2.8 MB    | ##################################### | 100%
# libtiff-4.4.0        | 504 KB    | ##################################### | 100%
# libcurl-7.86.0       | 335 KB    | ##################################### | 100%
# lcms2-2.14           | 248 KB    | ##################################### | 100%
# libcblas-3.9.0       | 13 KB     | ##################################### | 100%
# zstd-1.5.2           | 473 KB    | ##################################### | 100%
# fonttools-4.38.0     | 1.9 MB    | ##################################### | 100%
# jpeg-9e              | 260 KB    | ##################################### | 100%
# libwebp-base-1.2.4   | 385 KB    | ##################################### | 100%
# libblas-3.9.0        | 13 KB     | ##################################### | 100%
# basemap-1.3.6        | 144 KB    | ##################################### | 100%
# openssl-1.1.1s       | 1.6 MB    | ##################################### | 100%
# libopenblas-0.3.21   | 9.6 MB    | ##################################### | 100%
# packaging-23.0       | 40 KB     | ##################################### | 100%
# c-ares-1.18.1        | 100 KB    | ##################################### | 100%
# brotli-1.0.9         | 19 KB     | ##################################### | 100%
# unicodedata2-15.0.0  | 486 KB    | ##################################### | 100%
# munkres-1.1.4        | 12 KB     | ##################################### | 100%
# python-dateutil-2.8. | 240 KB    | ##################################### | 100%
# libbrotlienc-1.0.9   | 303 KB    | ##################################### | 100%
# pillow-9.3.0         | 689 KB    | ##################################### | 100%
# python_abi-3.9       | 4 KB      | ##################################### | 100%
# pyproj-3.3.1         | 455 KB    | ##################################### | 100%
# krb5-1.19.3          | 1.2 MB    | ##################################### | 100%
# cycler-0.11.0        | 10 KB     | ##################################### | 100%
# libgfortran5-11.3.0  | 1.4 MB    | ##################################### | 100%
# libssh2-1.10.0       | 221 KB    | ##################################### | 100%
# giflib-5.2.1         | 71 KB     | ##################################### | 100%
# pyshp-2.3.1          | 941 KB    | ##################################### | 100%
# matplotlib-base-3.5. | 7.4 MB    | ##################################### | 100%
# numpy-1.24.1         | 5.8 MB    | ##################################### | 100%
# libgfortran-5.0.0    | 143 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
plt.scatter(x=df['longitude'], y=df['latitude'])
plt.show()

# %%
gpd.datasets.available
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

geometry = [Point(xy) for xy in zip(df['longitude'], df['latitude'])]
gdf = GeoDataFrame(df, geometry=geometry)   

#this is a simple map that goes with geopandas

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15);

# %%
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

geometry = [Point(xy) for xy in zip(df['longitude'], df['latitude'])]
gdf = GeoDataFrame(df, geometry=geometry)   

#this is a simple map that goes with geopandas

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(column='gdp_per_cap', cmap='OrRd');
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gdp_per_cap'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [14], line 11
#       8 #this is a simple map that goes with geopandas
#      10 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---> 11 world.plot(column='gdp_per_cap', cmap='OrRd');
#      12 gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15)
#
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/geopandas/plotting.py:968, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     966 kind = kwargs.pop("kind", "geo")
#     967 if kind == "geo":
# --> 968     return plot_dataframe(data, *args, **kwargs)
#     969 if kind in self._pandas_kinds:
#     970     # Access pandas plots
#     971     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/geopandas/plotting.py:728, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     726             values = values.reindex(df.index)
#     727 else:
# --> 728     values = df[column]
#     730 if pd.api.types.is_categorical_dtype(values.dtype):
#     731     if categories is not None:
#
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/geopandas/geodataframe.py:1415, in GeoDataFrame.__getitem__(self, key)
#    1409 def __getitem__(self, key):
#    1410     """
#    1411     If the result is a column containing only 'geometry', return a
#    1412     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1413     return a GeoDataFrame.
#    1414     """
# -> 1415     result = super().__getitem__(key)
#    1416     geo_col = self._geometry_column_name
#    1417     if isinstance(result, Series) and isinstance(result.dtype, GeometryDtype):
#
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/pandas/core/frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'gdp_per_cap'

# %%
plt.figure(figsize=(15,8))
m = Basemap(projection = 'mill', llcrnrlat = -15, urcrnrlat = 5, llcrnrlon = 90, urcrnrlon = 150, resolution = 'h')
m.drawcoastlines()
m.drawcountries()

x, y = m(list(df["longitude"].astype(float)), list(df["latitude"].astype(float)))
m.plot(x, y, 'go', markersize = 12, alpha = 0.8, color = "#990099")

plt.title('Extinct Languages - Indonesia')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/mpl_toolkits/basemap/__init__.py:1236, in Basemap._readboundarydata(self, name, as_polygons)
#    1235 try:
# -> 1236     bdatfile = open(os.path.join(basemap_datadir,name+'_'+self.resolution+'.dat'),'rb')
#    1237     bdatmetafile = open(os.path.join(basemap_datadir,name+'meta_'+self.resolution+'.dat'),'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/opt/anaconda3/envs/iron/lib/python3.9/site-packages/mpl_toolkits/basemap_data/gshhs_h.dat'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In [8], line 2
#       1 plt.figure(figsize=(15,8))
# ----> 2 m = Basemap(projection = 'mill', llcrnrlat = -15, urcrnrlat = 5, llcrnrlon = 90, urcrnrlon = 150, resolution = 'h')
#       3 m.drawcoastlines()
#       4 m.drawcountries()
#
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/mpl_toolkits/basemap/__init__.py:1125, in Basemap.__init__(self, llcrnrlon, llcrnrlat, urcrnrlon, urcrnrlat, llcrnrx, llcrnry, urcrnrx, urcrnry, width, height, projection, resolution, area_thresh, rsphere, ellps, lat_ts, lat_1, lat_2, lat_0, lon_0, lon_1, lon_2, o_lon_p, o_lat_p, k_0, no_rot, suppress_ticks, satellite_height, boundinglat, fix_aspect, anchor, celestial, round, epsg, ax)
#    1121 # read in coastline polygons, only keeping those that
#    1122 # intersect map boundary polygon.
#    1123 if self.resolution is not None:
#    1124     self.coastsegs, self.coastpolygontypes =\
# -> 1125     self._readboundarydata('gshhs',as_polygons=True)
#    1126     # reformat for use in matplotlib.patches.Polygon.
#    1127     self.coastpolygons = []
#
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/mpl_toolkits/basemap/__init__.py:1239, in Basemap._readboundarydata(self, name, as_polygons)
#    1237     bdatmetafile = open(os.path.join(basemap_datadir,name+'meta_'+self.resolution+'.dat'),'r')
#    1238 except:
# -> 1239     raise IOError(msg)
#    1240 polygons = []
#    1241 polygon_types = []
#
# OSError: Unable to open boundary dataset file. Only the 'crude', 'low' and
# 'intermediate' resolution datasets are installed by default. If you
# are requesting a 'high' or 'full' resolution dataset, you need to
# install the `basemap-data-hires` package with
# `conda install -c conda-forge basemap-data-hires`.

# %% [markdown]
# ### KEPLER

# %%
#pip install keplergl

# %%
from keplergl import KeplerGl
map_1 = KeplerGl(height=400)
map_1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl()

# %%
config=hex_config
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 config=hex_config
#
# NameError: name 'hex_config' is not defined

# %%
map_2 = KeplerGl(height=400, data={'data_1': df}, config=config)
map_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 map_2 = KeplerGl(height=400, data={'data_1': df}, config=config)
#       2 map_2
#
# NameError: name 'config' is not defined

# %%
from keplergl import KeplerGl

# %%
from keplergl import KeplerGl
map_1 = KeplerGl()
map_1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl()

# %%
# Load kepler.gl with an empty map
from keplergl import KeplerGl
map_1 = KeplerGl(height=400)
map_1

# Load kepler.gl with map data and config
map_2 = KeplerGl(height=400, data={'data_1': df}, config=config)
map_2

# Add data to map
map_1.add_data(df, 'data_1')

# Apply config
map_1.config(config)

# print data and config
map_1.data
map_1.config

# save map to html
map_1.save_to_html(file_name='keplergl_map.html')
