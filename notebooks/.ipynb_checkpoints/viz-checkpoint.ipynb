# %%
#pip install folium

# %% [markdown]
# https://www.geomapik.com/desarrollo-programacion-gis/mapas-con-python-geopandas-matplotlib/https://www.geomapik.com/desarrollo-programacion-gis/mapas-plotly-visualizacion-datos-espaciales/
# https://github.com/chemaar/python-programming-course/blob/master/intro-data-science-tools-es/Visualizaci%C3%B3n-de-datos.ipynb

# %% [markdown]
# https://plotly.com/python/time-series/
# https://statologos.com/seaborn-heatmap/
# https://seaborn.pydata.org/examples/errorband_lineplots.html
# https://datacommons.org/place/country/USA?utm_medium=explore&mprop=fertilityRate&popt=Person&cpv=gender%2CFemale&hl=es

# %%
import folium 
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# import plotly.express as px
# from collections import Counter
# from fuzzywuzzy import process, fuzz
# import pickle
# import re

# %%
df= pd.read_csv("df_usa.csv")
df.head(4)
# Out:
#    Unnamed: 0          language           endangerment  latitude  longitude
# 0         156            Navajo             Vulnerable   35.8044  -108.4750
# 1         359             Sioux             Vulnerable   43.0588  -102.5244
# 2         443  O'odham (Akimel)  Definitely endangered   33.0590  -112.0479
# 3         444  O'odham (Tohono)  Definitely endangered   31.9186  -111.8798

# %% [markdown]
# ### Endargement

# %%
plt.figure(figsize = (8,5)) # para establecer el tamaño de la figura. Este tamaño solo se aplicará a esta figura 

plt.hist(df["endangerment"], edgecolor = "black", 
                        facecolor = "#0072BD", 
                        bins = 10)
plt.xticks(rotation=45);

# %%
df_states= pd.read_csv("df_usa_states.csv")
df_states.head(4)
# Out:
#    Unnamed: 0.1  Unnamed: 0          language           endangerment  \
# 0             0         156            Navajo             Vulnerable
# 1             1         359             Sioux             Vulnerable
# 2             2         443  O'odham (Akimel)  Definitely endangered
# 3             3         444  O'odham (Tohono)  Definitely endangered
#
#    latitude  longitude         state
# 0   35.8044  -108.4750       Arizona
# 1   43.0588  -102.5244  South Dakota
# 2   33.0590  -112.0479       Arizona
# 3   31.9186  -111.8798       Arizona

# %%
df_states['state'].unique()
# Out:
# array(['Arizona', 'South Dakota', 'Alaska', 'Oklahoma', 'Louisiana',
#        'Mississippi', 'New Mexico', 'Massachusetts', 'Minnesota',
#        'Montana', 'Québec', 'Idaho', 'Utah', 'Wyoming', 'North Carolina',
#        'Hawaii', 'Maine', 'Florida', 'Colorado', 'Michigan', nan,
#        'Kansas', 'Nevada', 'Oregon', 'Nebraska', 'Wisconsin',
#        'North Dakota', 'Iowa', 'California', 'New York', 'Washington',
#        'South Carolina', 'British Columbia', 'Pennsylvania', 'Maryland',
#        'New Hampshire'], dtype=object)

# %%
df_states['state'].value_counts()
# Out:
# California          54
# Alaska              24
# Oklahoma            24
# Arizona             14
# Oregon              14
# Washington          13
# New Mexico          12
# New York             6
# Montana              6
# Wisconsin            4
# Idaho                4
# Utah                 3
# North Dakota         3
# Louisiana            3
# Maine                2
# Colorado             2
# Michigan             2
# Kansas               2
# Nevada               2
# Mississippi          2
# Nebraska             2
# Wyoming              2
# British Columbia     1
# South Carolina       1
# Pennsylvania         1
# Maryland             1
# Florida              1
# Iowa                 1
# South Dakota         1
# Hawaii               1
# North Carolina       1
# Québec               1
# Minnesota            1
# Massachusetts        1
# New Hampshire        1
# Name: state, dtype: int64

# %%
df_states.groupby(by=['language','state']).mean()
# Out:
# /var/folders/3v/w3g18dxj3gz5w9dw0dh5z2z00000gn/T/ipykernel_13739/4273112722.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_states.groupby(by=['language','state']).mean()
#                             Unnamed: 0.1  Unnamed: 0  latitude  longitude
# language        state
# Achumawi        California         116.0      2076.0   40.8816  -122.6715
# Acoma-Laguna    New Mexico          17.0       768.0   34.8964  -107.5816
# Ahtna           Alaska             101.0      1985.0   62.7547  -144.3164
# Aleut (Eastern) Alaska              70.0      1691.0   54.7212  -164.4433
# Aleut (Western) Alaska              71.0      1692.0   52.2304  -174.1978
# ...                                  ...         ...       ...        ...
# ...

# %%
df_viz= df_states.groupby('endangerment').value_counts() 
df_viz.head()
# Out:
# endangerment           Unnamed: 0.1  Unnamed: 0  language                                          latitude  longitude  state
# Critically endangered  23            936         Seward Peninsula Inupiaq (King Island)            64.9728   -168.0616  Alaska        1
#                        24            937         Seward Peninsula Inupiaq (Little Diomede Island)  65.7550   -168.9167  Alaska        1
#                        104           1997        Upper Kuskokwim                                   63.0091   -154.3889  Alaska        1
#                        107           2033        Nez Perce                                         46.4347   -116.8268  Idaho         1
#                        108           2037        Panamint                                          36.4555   -116.8666  California    1
# dtype: int64

# %%
plt.figure(figsize =(20,8)) # para establecer el tamaño de la gráfica
fig = sns.countplot(data = df_states, x = "state",  
                    palette=sns.color_palette("YlOrBr"), 
                    order = df["endangerment"].value_counts().index) 
plt.xticks(rotation=45) # para girar las etiquetas del eje-x
plt.title("endangerment languages by state")

ejex = df["state"].value_counts().index.tolist()
ejey = df["endangerment"].value_counts().values.tolist()

plt.show();
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state'
#
# The above exception was the direct cause of the following exception:
#
# ...
