# %%
#pip install wbgapi
# Out:
# ...
#   Using cached PyYAML-6.0-cp39-cp39-macosx_10_9_x86_64.whl (197 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import wbgapi as wb

# %%
lista_={}

# %%
for row in wb.data.fetch('SP.POP.TOTL', 'USA'): # all years
    print(row)
# Out:
# {'value': 331893745, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2021'}
# {'value': 331501080, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2020'}
# {'value': 328329953, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2019'}
# {'value': 326838199, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2018'}
# {'value': 325122128, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2017'}
# {'value': 323071755, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2016'}
# {'value': 320738994, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2015'}
# {'value': 318386329, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2014'}
# {'value': 316059947, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2013'}
# ...

# %%
wb.data.DataFrame('SP.POP.TOTL', 'USA', range(1970,2005), version=range(201004,202004,100), db=57)
# Out:
#               YR1970       YR1971       YR1972       YR1973       YR1974  \
# version
# 201004   205052000.0  207661000.0  209896000.0  211909000.0  213854000.0
# 201104   205052000.0  207661000.0  209896000.0  211909000.0  213854000.0
# 201204   205052000.0  207661000.0  209896000.0  211909000.0  213854000.0
# 201304   205052000.0  207661000.0  209896000.0  211909000.0  213854000.0
# 201404   205052000.0  207661000.0  209896000.0  211909000.0  213854000.0
# 201504   205052000.0  207661000.0  209896000.0  211909000.0  213854000.0
# 201604   205052000.0  207661000.0  209896000.0  211909000.0  213854000.0
# 201704   205052000.0  207661000.0  209896000.0  211909000.0  213854000.0
# 201804   205052000.0  207661000.0  209896000.0  211909000.0  213854000.0
# 201904   205052000.0  207661000.0  209896000.0  211909000.0  213854000.0
#
#               YR1975       YR1976       YR1977       YR1978       YR1979  ...  \
# ...

# %%
wb.data.DataFrame('SP.POP.TOTL', 'USA', range(1970,2005), version=range(201004,202004,100), db=57)

# %%
wb.data.DataFrame('SP.POP.TOTL', 'USA','&for=state', range(1970,2005), version=range(201004,202004,100), db=57)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 wb.data.DataFrame('SP.POP.TOTL', 'USA','&for=state', range(1970,2005), version=range(201004,202004,100), db=57)
#
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/wbgapi/data.py:317, in DataFrame(series, economy, time, index, columns, mrv, mrnev, skipBlanks, labels, skipAggs, numericTimeKeys, timeColumns, params, db, **dimensions)
#     314     raise ValueError('columns must be None or a dimension')
#     316 if type(index) is not list or len(set(index) - set(concepts)) > 0:
# --> 317     raise ValueError('index must be None or a dimension list')
#     319 if columns in index:
#     320     raise ValueError('columns cannot be an element in index')
#
# ValueError: index must be None or a dimension list
