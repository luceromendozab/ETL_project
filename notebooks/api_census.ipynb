# %%
import pandas as pd
import requests
import json
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
token = os.getenv("token")

# %%
print(token)
# Out:
# maJGB0ps9abMa2w0Me84eqqIRZkyLPlQ

# %%
url= 'https://api.census.gov/data'
year = '/2019'
dataset_value= '/pep/population'
call= '?get='
variables = 'NAME,POP,SEX,AGE'
location = '&for=state:*'
api_key = f"&key={token}"

# %%
url_call=f"{url}{year}{dataset_value}{call}{variables}{location}{api_key}"

# %%
result=requests.get(url_call)

# %%
result.status_code
# Out:
# 200

# %%
data_=result.json()
data_
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/anaconda3/envs/iron/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
result.text
# Out:
# '\n<html>\n    <head>\n        <title>Invalid Key</title>\n    </head>\n    <body>\n        <p>\n            A valid <em>key</em> must be included with each data API request.\n            You included a key with this request, however, it is not valid.\n            Please check your key and try again.\n        </p>\n        <p>\n            If you do not have a key you may sign up for one <a href="key_signup.html">here</a>.\n        </p>\n    </body>\n</html>\n'

# %%
data_=result.json()
df_2019=pd.DataFrame(data_)
df_2019
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/anaconda3/envs/iron/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
result=requests.get(url_call)

# %%
result.status_code
# Out:
# 200

# %%
result.reason
# Out:
# ''

# %%
data=result.json()
df_2019=pd.DataFrame(data)
df_2019
# Out:
#                        0         1      2
# 0                   NAME       POP  state
# 1                Alabama   4903185     01
# 2                 Alaska    731545     02
# 3                Arizona   7278717     04
# 4               Arkansas   3017804     05
# 5             California  39512223     06
# 6               Colorado   5758736     08
# 7               Delaware    973764     10
# 8   District of Columbia    705749     11
# 9            Connecticut   3565287     09
# 10               Florida  21477737     12
# 11               Georgia  10617423     13
# 12                 Idaho   1787065     16
# 13                Hawaii   1415872     15
# 14              Illinois  12671821     17
# 15               Indiana   6732219     18
# 16                  Iowa   3155070     19
# 17                Kansas   2913314     20
# 18              Kentucky   4467673     21
# 19             Louisiana   4648794     22
# 20                 Maine   1344212     23
# ...

# %% [markdown]
# -------
# Pruebas con Ana

# %%
for año in range(1990, 2021):
    for i in range(1,13):
        url3 = f"https://api.census.gov/data/{año}/pep/natstprc?get=STNAME,POP&DATE_={i}&for=state:*"
        res3 = requests.get(url3)
        print(año, "----", i, "---", res3.status_code)
    print("----------------")
# Out:
# 1990 ---- 1 --- 404
# 1990 ---- 2 --- 404
# 1990 ---- 3 --- 404
# 1990 ---- 4 --- 404
# 1990 ---- 5 --- 404
# 1990 ---- 6 --- 404
# 1990 ---- 7 --- 404
# 1990 ---- 8 --- 404
# 1990 ---- 9 --- 404
# 1990 ---- 10 --- 404
# 1990 ---- 11 --- 404
# 1990 ---- 12 --- 404
# ----------------
# 1991 ---- 1 --- 404
# 1991 ---- 2 --- 404
# 1991 ---- 3 --- 404
# 1991 ---- 4 --- 404
# 1991 ---- 5 --- 404
# 1991 ---- 6 --- 404
# 1991 ---- 7 --- 404
# 1991 ---- 8 --- 404
# 1991 ---- 9 --- 404
# 1991 ---- 10 --- 404
# 1991 ---- 11 --- 404
# 1991 ---- 12 --- 404
# ----------------
# 1992 ---- 1 --- 404
# 1992 ---- 2 --- 404
# 1992 ---- 3 --- 404
# 1992 ---- 4 --- 404
# 1992 ---- 5 --- 404
# 1992 ---- 6 --- 404
# 1992 ---- 7 --- 404
# 1992 ---- 8 --- 404
# 1992 ---- 9 --- 404
# 1992 ---- 10 --- 404
# 1992 ---- 11 --- 404
# 1992 ---- 12 --- 404
# ----------------
# 1993 ---- 1 --- 404
# 1993 ---- 2 --- 404
# 1993 ---- 3 --- 404
# 1993 ---- 4 --- 404
# 1993 ---- 5 --- 404
# 1993 ---- 6 --- 404
# ...

# %%
res3 = requests.get(url3)
res3.status_code
# Out:
# 200

# %%
res3.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/anaconda3/envs/iron/lib/python3.9/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/anaconda3/envs/iron/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %% [markdown]
# -------

# %%
#parameters. for race
dataset_race= '/pep/charagegroups'
variables_race = 'NAME,RACE,POP'

# %%
res_race = f"{url}{year}{dataset_race}{call}{variables_race}{location}{api_key}"

# %%
result_race=requests.get(res_race)

# %%
result_race.status_code
# Out:
# 200

# %%
data_race=result_race.json()
df_race=pd.DataFrame(data_race)
df_race
# Out:
#                0     1        2      3
# 0           NAME  RACE      POP  state
# 1    Mississippi     0  2976149     28
# 2    Mississippi     1  1758081     28
# 3    Mississippi     2  1124559     28
# 4    Mississippi     3    18705     28
# ..           ...   ...      ...    ...
# 609    Minnesota     7  4859412     27
# 610    Minnesota     8   469537     27
# 611    Minnesota     9   124345     27
# 612    Minnesota    10   335109     27
# 613    Minnesota    11     9454     27
#
# [614 rows x 4 columns]

# %%
t= f"{url}{year_a}{dataset_value}{call}{variables}{location}{api_key}"

# %%
result_t=requests.get(t)

# %%
result_t.status_code
# Out:
# 404

# %%
url = f"https://api.census.gov/data/timeseries/pep/population&key={api_key}"

https://api.census.gov/data/timeseries/pep/population
# Out:
#   Cell In [140], line 3
#     https://api.census.gov/data/timeseries/pep/population
#           ^
# SyntaxError: invalid syntax

# %%
rs = requests.get(url)

# %%
rs.status_code
# Out:
# 404

# %%
data_rs = rs.json()
print(data_rs)

# %%
res_race = f"{url}{year}{dataset_race}{call}{variables_race}{location}{api_key}"
